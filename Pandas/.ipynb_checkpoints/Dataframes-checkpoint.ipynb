# %%
import numpy as np
import pandas as pd

# %%
data = {
    "name": ["Amit", "Riya", "Karan", "Neha"],
    "age": [25, 28, 30, 26],
    "salary": [40000, 50000, 55000, 45000],
    "city": ["Delhi", "Mumbai", "Bangalore", "Chennai"]
}
pd.DataFrame(data)
# Out:
#     name  age  salary       city
# 0   Amit   25   40000      Delhi
# 1   Riya   28   50000     Mumbai
# 2  Karan   30   55000  Bangalore
# 3   Neha   26   45000    Chennai

# %%
dataList = [['Amit', 25, 40000, 'Delhi'],
 ['Riya', 28, 50000, 'Mumbai'],
 ['Karan', 30, 55000, 'Bangalore'],
 ['Neha', 26, 45000, 'Chennai']]
pd.DataFrame(dataList)
# Out:
#        0   1      2          3
# 0   Amit  25  40000      Delhi
# 1   Riya  28  50000     Mumbai
# 2  Karan  30  55000  Bangalore
# 3   Neha  26  45000    Chennai

# %%
columns = ['Name', 'Age','Salary' , 'City']
df2 = pd.DataFrame(dataList, columns=columns)
df2
# Out:
#     Name  Age  Salary       City
# 0   Amit   25   40000      Delhi
# 1   Riya   28   50000     Mumbai
# 2  Karan   30   55000  Bangalore
# 3   Neha   26   45000    Chennai

# %%
df2[['Name','Age']]
# Out:
#     Name  Age
# 0   Amit   25
# 1   Riya   28
# 2  Karan   30
# 3   Neha   26

# %%
df2['Designation'] = ['doctor','eng','teach','stud']

# %%
df2
# Out:
#     Name  Age  Salary       City Designation
# 0   Amit   25   40000      Delhi      doctor
# 1   Riya   28   50000     Mumbai         eng
# 2  Karan   30   55000  Bangalore       teach
# 3   Neha   26   45000    Chennai        stud

# %%
df2.drop('Designation',axis=1)
# Out:
#     Name  Age  Salary       City
# 0   Amit   25   40000      Delhi
# 1   Riya   28   50000     Mumbai
# 2  Karan   30   55000  Bangalore
# 3   Neha   26   45000    Chennai

# %%
df2
# Out:
#     Name  Age  Salary       City Designation
# 0   Amit   25   40000      Delhi      doctor
# 1   Riya   28   50000     Mumbai         eng
# 2  Karan   30   55000  Bangalore       teach
# 3   Neha   26   45000    Chennai        stud

# %%
df2.drop('Designation',axis=1,inplace = True)

# %%
df2
# Out:
#     Name  Age  Salary       City
# 0   Amit   25   40000      Delhi
# 1   Riya   28   50000     Mumbai
# 2  Karan   30   55000  Bangalore
# 3   Neha   26   45000    Chennai

# %%
df2.loc[0]
# Out:
# Name       Amit
# Age          25
# Salary    40000
# City      Delhi
# Name: 0, dtype: object

# %%
df2.loc[[0,1]]
# Out:
#    Name  Age  Salary    City
# 0  Amit   25   40000   Delhi
# 1  Riya   28   50000  Mumbai

# %%
df2.loc[[0,1]][['Salary','City']]
# Out:
#    Salary    City
# 0   40000   Delhi
# 1   50000  Mumbai

# %%
df2.loc[[2,3]][['Name','Age']]
# Out:
#     Name  Age
# 2  Karan   30
# 3   Neha   26

# %%
df2[df2['Age'] > 20]
# Out:
#     Name  Age  Salary       City
# 0   Amit   25   40000      Delhi
# 1   Riya   28   50000     Mumbai
# 2  Karan   30   55000  Bangalore
# 3   Neha   26   45000    Chennai

# %%
df2[(df2['Age'] > 20) & (df2['City'] == 'Delhi')]
# Out:
#    Name  Age  Salary   City
# 0  Amit   25   40000  Delhi
