# %%
import numpy as np
import pandas as pd

# %%
labels = ('a','b','c')
my_list = [1,2,3]
arr = np.array([10,20,30])
d = {1:12,2:23,3:34}

# %%
pd.Series(my_list,index=labels)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(d)
# Out:
# 1    12
# 2    23
# 3    34
# dtype: int64
